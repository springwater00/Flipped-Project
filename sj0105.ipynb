# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

from matplotlib import rc
# rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False
from matplotlib import font_manager, rc
font_path = 'C:/Windows/Fonts/malgun.ttf'
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

import missingno as msno # 결측치를 확인할 수 있는 라이브러리
import os
import sys

# 경고 문구 off
import warnings
warnings.filterwarnings('ignore')

# 컬럼 표시 제한
# pd.set_option('display.max_row', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# # 1. 상황인식

# %% [markdown]
# 1.배경
#
# 안녕하세요 여러분! 구내식당 식수 인원 예측 AI 경진대회에 오신 것을 환영합니다.
#
# 지금까지는 단순한 시계열 추세와 담당자의 직관적 경험에 의존하여한국토지주택공사 구내식당 식수 인원을 예측하였으나,
#
# 빅데이터 분석으로 얻어지는 보다 정확도 높은 예측을 통해 "잔반 발생량을 획기적으로 줄이고자" 합니다.
#
#
# 2.목적
#
# 구내식당의 요일별 점심, 저녁식사를 먹는 인원을 예측
#
# ___________________________________________________________________________________________________________________
#
#
# 3.	평가
#
# 평가산식 : MAE(Mean Absolute Error)
# Public 평가 : 전체 Test 데이터 중 무작위 30 % (15일)
# Private 평가 : 전체 Test 데이터 중 나머지 70 % (35일)
#
#
# 4. 외부 데이터 및 사전학습 모델
#
# 공공 데이터와 같이 누구나 얻을 수 있고 법적 제약이 없는 외부 데이터 허용
# 사전학습 모델의 경우 사전학습에 사용된 데이터를 명시해야함
# 최종 평가시 외부데이터 및 출처 제출
#
#
# 5. 코드 평가
#
# 다음 조건을 만족하며 제출한 코드로 Private score가 복원된 상위 3팀에게 상금을 수여합니다.
# 조건 1. Private 순위 공개 후 코드 제출 기간 내 코드 코드공유 게시판 게시한 팀(설명 PPT dacon@dacon.io로 제출)
# 			제목 양식 : 팀이름, Private 순위와 Private 점수, 모델 이름
#
# 			내 용 : 전처리, 학습, 후처리, 추론 일련의 과정을 담은 코드를 게시
#
# 			예시) 데이콘팀, Private 1위, Private 점수 : 5.23, ResNet

# %% [markdown]
# # 2. 데이터 분석

# %% [markdown]
# >## 1) 데이터 불러오기

# %%
train_df = pd.read_csv('restaurant/train.csv')
train_df.head(1)
# Out:
#            일자 요일  본사정원수  본사휴가자수  본사출장자수  본사시간외근무명령서승인건수  현본사소속재택근무자수  \
# 0  2016-02-01  월   2601      50     150             238          0.0
#
#                                                 조식메뉴  \
# 0  모닝롤/찐빵  우유/두유/주스 계란후라이  호두죽/쌀밥 (쌀:국내산) 된장찌개  쥐...
#
#                                                 중식메뉴  \
# 0  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 오징어찌개  쇠불고기 (쇠고기:호주산) 계란찜 ...
#
#                                                 석식메뉴     중식계    석식계
# 0  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 육개장  자반고등어구이  두부조림  건파래무침 ...  1039.0  331.0

# %%
test_df = pd.read_csv('restaurant/test.csv')
test_df.head(1)
# Out:
#            일자 요일  본사정원수  본사휴가자수  본사출장자수  본사시간외근무명령서승인건수  현본사소속재택근무자수  \
# 0  2021-01-27  수   2983      88     182               5        358.0
#
#                                                 조식메뉴  \
# 0  모닝롤/연유버터베이글 우유/주스 계란후라이/찐계란 단호박죽/흑미밥 우거지국 고기완자...
#
#                                                 중식메뉴  \
# 0  쌀밥/흑미밥/찰현미밥 대구지리 매운돈갈비찜 오꼬노미계란말이 상추무침 포기김치 양상추...
#
#                                             석식메뉴
# 0  흑미밥 얼큰순두부찌개 쇠고기우엉볶음 버섯햄볶음 (New)아삭이고추무절임 포기김치

# %%
submission_df = pd.read_csv('restaurant/sample_submission.csv')
submission_df.head()
# Out:
#            일자  중식계  석식계
# 0  2021-01-27    0    0
# 1  2021-01-28    0    0
# 2  2021-01-29    0    0
# 3  2021-02-01    0    0
# 4  2021-02-02    0    0

# %% [markdown]
# ### 컬럼정리

# %%
train_df['일자'] = train_df['일자'].str.replace('-', '')
train_df.insert(0, 'date', train_df['일자'].str[2:8])
train_df.insert(1, 'year', train_df['일자'].str[:4])
train_df.insert(2, 'month', train_df['일자'].str[4:6])
train_df.insert(3, 'day', train_df['일자'].str[6:])
train_df.columns=['date','year','month','day','일자','요일','정원','휴가자','출장자','시간외근무','재택근무','조식','중식','석식','중식계','석식계']
train_df.insert(11, '근무중인원', train_df['정원']-train_df['휴가자']-train_df['출장자']+train_df['시간외근무']-train_df['재택근무'])

train_df.head(1)
# Out:
#      date  year month day        일자 요일    정원  휴가자  출장자  시간외근무  재택근무   근무중인원  \
# 0  160201  2016    02  01  20160201  월  2601   50  150    238   0.0  2639.0
#
#                                                   조식  \
# 0  모닝롤/찐빵  우유/두유/주스 계란후라이  호두죽/쌀밥 (쌀:국내산) 된장찌개  쥐...
#
#                                                   중식  \
# 0  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 오징어찌개  쇠불고기 (쇠고기:호주산) 계란찜 ...
#
#                                                   석식     중식계    석식계
# 0  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 육개장  자반고등어구이  두부조림  건파래무침 ...  1039.0  331.0

# %%
train_df['재택근무'] = train_df['재택근무'].astype(int)
train_df['중식계'] = train_df['중식계'].astype(int)
train_df['석식계'] = train_df['석식계'].astype(int)
train_df.head(1)
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1205 entries, 0 to 1204
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1205 non-null   object
#  1   year    1205 non-null   object
#  2   month   1205 non-null   object
#  3   day     1205 non-null   object
#  4   일자      1205 non-null   object
#  5   요일      1205 non-null   object
#  6   정원      1205 non-null   int64
#  7   휴가자     1205 non-null   int64
#  8   출장자     1205 non-null   int64
#  9   시간외근무   1205 non-null   int64
#  10  재택근무    1205 non-null   int32
#  11  근무중인원   1205 non-null   float64
#  12  조식      1205 non-null   object
#  13  중식      1205 non-null   object
#  14  석식      1205 non-null   object
#  15  중식계     1205 non-null   int32
#  16  석식계     1205 non-null   int32
# dtypes: float64(1), int32(3), int64(4), object(9)
# memory usage: 146.0+ KB

# %%
test_df['일자'] = test_df['일자'].str.replace('-', '')
test_df.insert(0, 'date', test_df['일자'].str[2:8])
test_df.columns=['date','일자','요일','정원','휴가자','출장자','시간외근무','재택근무','조식','중식','석식']
test_df.insert(8, '근무중인원', test_df['정원']-test_df['휴가자']-test_df['출장자']+test_df['시간외근무']-test_df['재택근무'])

test_df.head(1)
# Out:
#      date        일자 요일    정원  휴가자  출장자  시간외근무   재택근무   근무중인원  \
# 0  210127  20210127  수  2983   88  182      5  358.0  2360.0
#
#                                                   조식  \
# 0  모닝롤/연유버터베이글 우유/주스 계란후라이/찐계란 단호박죽/흑미밥 우거지국 고기완자...
#
#                                                   중식  \
# 0  쌀밥/흑미밥/찰현미밥 대구지리 매운돈갈비찜 오꼬노미계란말이 상추무침 포기김치 양상추...
#
#                                               석식
# 0  흑미밥 얼큰순두부찌개 쇠고기우엉볶음 버섯햄볶음 (New)아삭이고추무절임 포기김치

# %%
test_df['재택근무'] = train_df['재택근무'].astype(int)
test_df.head(1)
# Out:
#      date        일자 요일    정원  휴가자  출장자  시간외근무  재택근무   근무중인원  \
# 0  210127  20210127  수  2983   88  182      5     0  2360.0
#
#                                                   조식  \
# 0  모닝롤/연유버터베이글 우유/주스 계란후라이/찐계란 단호박죽/흑미밥 우거지국 고기완자...
#
#                                                   중식  \
# 0  쌀밥/흑미밥/찰현미밥 대구지리 매운돈갈비찜 오꼬노미계란말이 상추무침 포기김치 양상추...
#
#                                               석식
# 0  흑미밥 얼큰순두부찌개 쇠고기우엉볶음 버섯햄볶음 (New)아삭이고추무절임 포기김치

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    50 non-null     object
#  1   일자      50 non-null     object
#  2   요일      50 non-null     object
#  3   정원      50 non-null     int64
#  4   휴가자     50 non-null     int64
#  5   출장자     50 non-null     int64
#  6   시간외근무   50 non-null     int64
#  7   재택근무    50 non-null     int32
#  8   근무중인원   50 non-null     float64
#  9   조식      50 non-null     object
#  10  중식      50 non-null     object
#  11  석식      50 non-null     object
# dtypes: float64(1), int32(1), int64(4), object(6)
# memory usage: 4.6+ KB

# %%
msno.matrix(df=train_df.iloc[:, :], color=(0.2, 0.2, 0.9), figsize=(15, 5));
msno.matrix(df=test_df.iloc[:, :], color=(0.2, 0.2, 0.9), figsize=(15, 5));

# %% [markdown]
# ### 텍스트 정리

# %%
import re

def split_text(stringData):

    text = re.sub(r'\([^)]*\)', repl='', string=stringData)        
    text = text.replace('/',' ')
    text = text.replace('  ',' ')
    text = text.replace('*',' ')
    return text

# %%
train_df['조식'] = train_df['조식'].apply(split_text)
train_df['중식'] = train_df['중식'].apply(split_text)
train_df['석식'] = train_df['석식'].apply(split_text)

test_df['조식'] = train_df['조식'].apply(split_text)
test_df['중식'] = train_df['중식'].apply(split_text)
test_df['석식'] = train_df['석식'].apply(split_text)

print(train_df['조식'][0])
print(train_df['중식'][0])
print(train_df['석식'][0])
print()
print(test_df['조식'][0])
print(test_df['중식'][0])
print(test_df['석식'][0])
# Out:
# 모닝롤 찐빵 우유 두유 주스 계란후라이 호두죽 쌀밥 된장찌개 쥐어채무침 포기김치
# 쌀밥 잡곡밥 오징어찌개 쇠불고기 계란찜 청포묵무침 요구르트 포기김치
# 쌀밥 잡곡밥 육개장 자반고등어구이 두부조림 건파래무침 포기김치
#
# 모닝롤 찐빵 우유 두유 주스 계란후라이 호두죽 쌀밥 된장찌개 쥐어채무침 포기김치
# 쌀밥 잡곡밥 오징어찌개 쇠불고기 계란찜 청포묵무침 요구르트 포기김치
# 쌀밥 잡곡밥 육개장 자반고등어구이 두부조림 건파래무침 포기김치

# %%
morning_menu_list = []
lunch_menu_list = []
dinner_menu_list = []

for i in train_df['조식']:
    tmp_data = i.split(' ')
    #print(tmp_data)
    for j in tmp_data:
        morning_menu_list.append(j)
        
for i in train_df['중식']:
    tmp_data = i.split(' ')
    #print(tmp_data)
    for j in tmp_data:
        lunch_menu_list.append(j)
        
for i in train_df['석식']:
    tmp_data = i.split(' ')
    #print(tmp_data)
    for j in tmp_data:
        dinner_menu_list.append(j)
        
morning_menu_list[0]
# Out:
# '모닝롤'

# %%
type(morning_menu_list)
# Out:
# list

# %%
list(set(morning_menu_list))
# Out:
# ['',
#  '차돌박이찌개',
#  '모듬묵샐러드',
#  '올갱이아욱국',
#  '아삭고추된장무침',
#  '모카카스테라',
#  '방풍나물',
#  '콩나물김칫국',
#  '브로콜리감자볶음',
#  '햄에그샌드',
#  '황태해장국',
#  '감자양파국',
#  '황태채국',
#  '취나물볶음',
#  '호밧젓국찌개',
#  '선지해장국',
#  '토스트',
#  '에그포테이토샌드위치',
#  '오징어콩나물국',
#  '모시조개시금치국',
#  '대구매운탕',
#  '햄야채샌드',
#  '얼갈이겉절이',
#  '메론롤케익',
#  '콩나물된장국',
#  '대구찌개',
#  '호박나물',
#  '통아몬드멸치볶음',
#  '건포도머핀',
#  '어묵토마토조림',
#  '시금치샐러드',
#  '바나나베이비샐러드',
#  '불고기브리또',
#  '흑미두부죽',
#  '호박맑은국',
#  '차돌박이된장찌개',
#  '취나물된장무침',
#  '모둠장조림',
#  '모듬묵',
#  '사과롤케익',
#  '건새우무국',
#  '롤케익',
#  '조갯살근대국',
#  '바지락콩나물국',
#  '사골파국',
#  '양념',
#  '녹차카스테라',
#  '오징어국',
#  '병아리',
#  '대구지리탕',
#  '사각어묵볶음',
#  '김치국',
#  '허니브레드',
#  '블루베리프렌치토스트',
#  '크림치즈프레즐',
#  '냉이국',
#  '방풍나물무침',
#  '치즈팡샌드',
#  '달래양념장',
#  '시래기지짐',
#  '고구마순볶음',
#  '단배추들깨무침',
#  '무나물',
#  '흑미밥',
#  '컵케익',
#  '돈육마늘장조림',
#  '베이컨에그슬럿',
#  '김치도토리묵무침',
#  '계란찜',
#  '고사리들깨나물',
#  '에그샐러드',
#  '홍합살무국',
#  '맑은버섯육개장',
#  '느타리버섯볶음',
#  '어묵고추장볶음',
#  '자반김',
#  '프렌치토스트',
#  '김구이',
#  '무청된장국',
#  '김치황태국',
#  '오징어젓갈무침',
#  '실곤약흑임자무침',
#  '수제비국',
#  '봄동나물',
#  '도라지생채',
#  '매콤사태찜',
#  '얼갈이국',
#  '버섯햄볶음',
#  '섭산적구이',
#  '바나나팬케이크',
#  '돈육장조림',
#  '후르츠산도',
#  '소라살죽',
#  '근대국',
#  '검정콩조림',
#  '피바지락국',
#  '해물완자전',
#  '민물새우찌깨',
#  '명엽체고추장볶음',
#  '증편',
#  '두부조림',
#  '채소죽',
#  '베이컨맥모닝',
#  '연두부국',
#  '에그단호박샌드',
#  '새우살미역국',
#  '콥샐러드',
#  '감자햄볶음',
#  '열무김치',
#  '치킨샌드',
#  '수제어묵볶음',
#  '페퍼로니피자',
#  '토마토샌드',
#  '닭살해장국',
#  '메추리알조림',
#  '마늘쫑볶음',
#  '유자D',
#  '홍합탕',
#  '동전문어조림',
#  '누룽지',
#  '토마토리코타치즈샐러드',
#  '버섯매운탕',
#  '마계토스트',
#  '알탕',
#  '에그맥모닝',
#  '김칫국',
#  '순두부백탕',
#  '시래기된장국',
#  '열무된장국',
#  '연두부샐러드',
#  '무생채',
#  '섭산적채소조림',
#  '렌틸콩샐러드',
#  '수삼닭죽',
#  '두부쑥갓무침',
#  '순두부찌개',
#  '깻순나물',
#  '새알만두국',
#  '크로아상샌드위치',
#  '지리멸치볶음',
#  '토마토샐러드',
#  '쑥갓나물',
#  '도라지나물',
#  '오이맛살볶음',
#  '아욱국',
#  '크래미샌드',
#  '발사믹드레싱',
#  '진미채간장조림',
#  '양념깻잎지찜',
#  '석류D',
#  '매운소고기국',
#  '고르곤졸라피자',
#  '고들빼기무침',
#  '김치두부국',
#  '쑥갓무침',
#  '두부김칫국',
#  '느타리호박볶음',
#  '새송이죽',
#  '북어해장국',
#  '시래기들깨탕',
#  '김가루잔파무침',
#  '치커리유자무침',
#  '콩가루배추국',
#  '아메리카노',
#  '치커리무침',
#  '팥죽',
#  '두부브로컬리무침',
#  '미나리나물',
#  '버섯들깨탕',
#  '아귀지리',
#  '크래미숙주무침',
#  '호박고구마오븐구이',
#  '소고기무국',
#  '고구마죽',
#  '들깨버섯국',
#  '크랜베리멸치볶음',
#  '순두부된장국',
#  '메추리알곤약조림',
#  '만두국',
#  '갈릭파이',
#  '알타리김치',
#  '계란후라이',
#  '얼갈이나물',
#  '마늘쫑새우볶음',
#  '단호박샌드',
#  '소고기채소죽',
#  '명엽채볶음',
#  '연근땅콩조림',
#  '롤케이크',
#  '건새우아욱국',
#  '소고기죽',
#  '흑임자죽',
#  '시금치초무침',
#  '버섯맑은국',
#  '맑은만두국',
#  '통마늘너비아니조림',
#  '파래김',
#  '쇠고기샤브국',
#  '조랭이떡미역국',
#  '머위대나물',
#  '블루베리크림치즈베이글',
#  '시금치국',
#  '꽈리고추멸치볶음',
#  '새우살죽>',
#  '모닝롤',
#  '버섯들깨죽',
#  '토마토샌드위치',
#  '표고버섯죽',
#  '애플파이',
#  '촉촉한치즈빵',
#  '파운드케익',
#  '감자된장찌개',
#  '닭개장',
#  '유부장국',
#  '고르곤졸라',
#  '새송이버섯죽',
#  '우엉어묵볶음',
#  '소보루빵',
#  '호박새우젓국',
#  '수박',
#  '참나물생채',
#  '구운어묵볶음',
#  '참치김치찌개',
#  '숙주미나리나물',
#  '모닝에그빵',
#  '햄치즈샌드위치',
#  '시금치나물',
#  '김치콩나물국',
#  '꿀호떡',
#  '토란탕',
#  '도토리묵',
#  '브로컬리된장무침',
#  '치즈베이글',
#  '땅콩크림빵',
#  '참나물땅콩가루무침',
#  '시래기나물',
#  '연근조림',
#  '양념장',
#  '아귀채무침',
#  '깻잎순나물볶음',
#  '순두부계란국',
#  '애호박볶음',
#  '리코타치즈샐러드',
#  '핫도그',
#  '유채된장무침',
#  '콩나물국',
#  '오이사과무침',
#  '우거지해장국',
#  '핫케익',
#  '배추시래기국',
#  '카레감자채볶음',
#  '생깻잎지',
#  '인절미토스트',
#  '소보로빵',
#  '쥐포무침',
#  '북어채국',
#  '순두부국',
#  '비엔나곤약조림',
#  '고구마줄기볶음',
#  '장',
#  '소스',
#  '낙지죽',
#  '초장',
#  '명엽채무침',
#  '쌀밥',
#  '쇠고기해장국',
#  '와플&생크림',
#  '카스테라',
#  '깨찰빵',
#  '홍게살죽',
#  '애호박새우젓볶음',
#  '팥호빵',
#  '시금치나물무침',
#  '비엔나브로콜리볶음',
#  '낙지김치죽',
#  '오이무침',
#  '돈사태찜',
#  '인기가요샌드',
#  '유채나물',
#  '피자빵',
#  '브로컬리',
#  '옹심이만두국',
#  '절편',
#  '피홍합탕',
#  '사과베이비샐러드',
#  '머핀',
#  '베이컨숙주굴소스볶음',
#  '깻잎순볶음',
#  '스크램블에그',
#  '재첩국',
#  '샐러드',
#  '어묵매운국',
#  '김잔파무침',
#  '남친샌드위치',
#  '호떡맥모닝',
#  '견과류죽',
#  '베이컨치즈베이글',
#  '삼색샌드위치',
#  '호박새우젓찌개',
#  '맑은만두육개장',
#  '두부젓국찌개',
#  '영양부추생채',
#  '멸치크랜베리볶음',
#  '참치야채',
#  '오렌지케익빵',
#  '시금치두부무침',
#  '들깨감자국',
#  '멸치볶음',
#  '오이도라지무침',
#  '닭죽',
#  '바지락쑥국',
#  '매운감자국',
#  '오이생채',
#  '볼어묵조림',
#  '쇠고기버섯국',
#  '치즈볼',
#  '톳무침',
#  '동전쥐포무침',
#  '버섯비엔나조림',
#  '애플잼쿠키',
#  '고구마오븐구이',
#  '옥수수스프',
#  '홍합죽',
#  '건파래볶음',
#  '매생이떡국',
#  '스태프핫도그',
#  '크렌베리멸치볶음',
#  '망고드레싱',
#  '브로컬리무침',
#  '바지락무국',
#  '블루베리사과샌드',
#  '콩나물무침',
#  '올챙이만두국',
#  '오리엔탈D',
#  '우거지올갱이국',
#  '오렌지D',
#  '새우완자전',
#  '미역나물',
#  '베이비샐러드',
#  'BLT샌드위치',
#  '옥수수샌드',
#  '에그샌드',
#  '브로컬리두부무침',
#  '두부새우젓국',
#  '브로컬리들깨무침',
#  '아욱된장국',
#  '양념깻잎지',
#  '새우살야채죽',
#  '카야잼샌드',
#  '북어국',
#  '치즈케익',
#  '구이김',
#  '건새우무조림',
#  '청포묵무침',
#  '사과파이',
#  '시금치프리타타',
#  '인절미샌드',
#  '케익',
#  '섭산적조림',
#  '시래기국',
#  '햄야채볶음',
#  '식빵피자',
#  '마늘쫑건새우무침',
#  '모닝사라다빵',
#  '고구마순나물',
#  '감자국',
#  '조랭이떡국',
#  '두유',
#  '단호박크림스프',
#  '우거지국',
#  '곤약어묵볶음',
#  '맑은꽃게탕',
#  '쑥갓두부무침',
#  '동태탕',
#  '땅콩조림',
#  '아오리사과',
#  '바나나드레싱',
#  '모닝샌드',
#  '멸치캐슈넛볶음',
#  '겨울초나물',
#  '고구마샌드',
#  '고구마파이',
#  '매운감자조림',
#  '소고기샤브국',
#  '메론빵',
#  '죽순버섯볶음',
#  '유부김치국',
#  '야채샌드',
#  '참치샌드',
#  '쇠고기무국',
#  '조각케익',
#  '아귀지리탕',
#  '조랭이미역국',
#  '옛날소시지전',
#  '커피',
#  '민물새우찌개',
#  '사과잼쿠키',
#  '두부동그랑땡',
#  '된장찌개',
#  '숙주나물무침',
#  '고사리들깨볶음',
#  '콩나물간장조림',
#  '어묵고추장무침',
#  '계란장조림',
#  '보리누룽지탕',
#  '피자샌드',
#  '버섯굴죽',
#  '오징어무국',
#  '야채샌드위치',
#  '감자채피망볶음',
#  '미역줄기볶음',
#  '미역레몬초무침',
#  '땅콩죽',
#  '쇠고기마늘죽',
#  '시나몬페스츄리',
#  '칠리소스두부브로컬리볶음',
#  '호박채나물',
#  '크래미미역줄기볶음',
#  '브리또',
#  '게살채소죽',
#  '참치죽',
#  '김실파무침',
#  '와플',
#  '단호박찐빵',
#  '비엔나소세지볶음',
#  '사과샌드위치',
#  '가지나물',
#  '명엽채고추장볶음',
#  '케찹',
#  '바나나샌드',
#  '땅콩소스',
#  '소고기미역국',
#  '꽈리고추찜',
#  '스틱치즈케익',
#  '우엉땅콩조림',
#  '영양닭죽',
#  '쥐어채무침',
#  '양념김',
#  '가지두반장볶음',
#  '김자반',
#  '우엉조림',
#  '땅콩샌드',
#  '비엘티샌드위치',
#  '두부구이',
#  '청경채무침',
#  '매생이굴국',
#  '소시지볶음',
#  '후르츠팬케익',
#  '시금치고추장국',
#  '가자미양념찜',
#  '우렁살된장국',
#  '김가루실파무침',
#  '호두죽',
#  '버섯볶음',
#  '냉이바지락국',
#  '홍루이젠',
#  '마늘빵',
#  '건새우마늘쫑볶음',
#  '북어무우국',
#  '크로와상',
#  '아삭고추무침',
#  '쇠고기우거지국',
#  '황태국',
#  '브로컬리초장',
#  '열무된장나물',
#  '두부양념조림',
#  '길거리토스트',
#  '양송이죽',
#  '우엉채조림',
#  '분홍소세지구이',
#  '파래무침',
#  '해물땡굴소스볶음',
#  '얼갈이된장국',
#  '새송이볶음',
#  '버섯매운국',
#  '김치죽',
#  '카스텔라',
#  '버섯죽',
#  '새우야채죽',
#  '단팥죽',
#  '전주식콩나물국해장국',
#  '고기완자전&케찹',
#  '느타리버섯장조림',
#  '누룽지탕죽',
#  '쇠고기매운국',
#  '호빵',
#  '찐빵',
#  '참치야채죽',
#  '무채국',
#  '오이맛살냉채',
#  '계란빵',
#  '우유',
#  '멸치고추장무침',
#  '들깨시래기국',
#  '스크램블',
#  '쇠고기죽',
#  '감자샌드',
#  '감자채볶음',
#  '흑미쌀찐빵',
#  '연유후레쉬',
#  '피자토스트',
#  '팬케익',
#  '소고기스프',
#  '대구지리',
#  '스팸구이',
#  '삼겹살김치볶음',
#  '브로컬리죽',
#  '모둠묵',
#  '멸치아몬드볶음',
#  '단팥빵',
#  '양상추샐러드',
#  '얼큰소고기국',
#  '마약토스트',
#  '호박볶음',
#  '매운어묵국',
#  '참깨드레싱소스',
#  '참치모닝샌드',
#  '간장',
#  '비트무생채',
#  '콩죽',
#  '베이컨샌드위치',
#  '키위드레싱샐러드',
#  '양배추샐러드',
#  '구구마순나물',
#  '참나물두부샐러드',
#  '브로콜리맛살볶음',
#  '두부김치국',
#  '연두부',
#  '떡국',
#  '매운콩나물국',
#  '시금치핫케익',
#  '브로컬리들깨소스',
#  '비엔나야채볶음',
#  '미나리숙주무침',
#  '배추된장국',
#  '베이컨샌드',
#  '새우살죽',
#  '단호박죽',
#  '쑥갓겉절이',
#  '바지락죽',
#  '베이컨감자볶음',
#  '버섯국',
#  '미역죽',
#  '녹두죽',
#  '근대감자국',
#  '시금치죽',
#  '동태찌개',
#  '콩가루배춧국',
#  '쇠고기미역국',
#  '어묵탕',
#  '달래된장찌개',
#  '느타리버섯국',
#  '멸치호두볶음',
#  '깍두기',
#  '감자맛살볶음',
#  '미역소고기죽',
#  '마늘종숙회',
#  '감자조림',
#  '해초무침',
#  '누룽지탕',
#  '두부양념찜',
#  '새송이버섯볶음',
#  '애호박건새우볶음',
#  '참치채소죽',
#  '베이컨숙주볶음',
#  '배추겉절이',
#  '홍합살미역국',
#  '도라지볶음',
#  '노각무침',
#  '콩조림',
#  '들기름무채볶음',
#  '마샐러드',
#  '배추국',
#  '오곡죽',
#  '쪽파숙회',
#  '잣죽',
#  '매운버섯국',
#  '새알미역국',
#  '참나물',
#  '주스',
#  '마늘바게트',
#  '옹심이만두떡국',
#  '골뱅이무침',
#  '비엔나채소볶음',
#  '토란국',
#  '페스츄리',
#  '봄동된장국',
#  '야채소시지전',
#  '찐계란',
#  '호떡',
#  '브로콜리스프',
#  '맑은버섯국',
#  '씨크립샌드',
#  '생크림와플',
#  '진미채무침',
#  '북엇국',
#  '가지양파나물',
#  '취나물무침',
#  '프레즐',
#  '두부계란전',
#  '오리훈제샌드위치',
#  '단호박피자빵',
#  '감자찌개',
#  '몽골식돈육볶음',
#  '고추장찌개',
#  '게살모닝샌드위치',
#  '비타민샐러드',
#  '유채나물무침',
#  '꽃맛살볶음',
#  '옹심이만둣국',
#  '치커리사과무침',
#  '쿠키',
#  '모닝샌드위치',
#  '군대리아',
#  '호박죽',
#  '어묵꽈리고추볶음',
#  '포기김치',
#  '들깨무채국',
#  '느타리볶음',
#  '브라우니',
#  '감자채햄볶음',
#  '마늘쫑메추리알장조림',
#  '콩가루된장국',
#  '샌드위치',
#  '호박숙',
#  '가지양파무침',
#  '양념깻잎찜',
#  '밤죽',
#  '크로와상샌드위치',
#  '시래기조림',
#  '대추채멸치볶음',
#  '무채나물',
#  '바지락국',
#  '호박채볶음',
#  '보코치니샐러드',
#  '그린샐러드',
#  '북어맑은국',
#  '미니햄버거',
#  '에그타르트',
#  '방울양배추베이컨볶음',
#  '마늘쫑맛살볶음',
#  '사골우거지국',
#  '홍초콩나물국',
#  '시금치된장국',
#  '에그갈릭토스트',
#  '야채호빵',
#  '치커리유자청무침',
#  '어묵국',
#  '오렌지빵',
#  '양송이스프',
#  '피바지락배추국',
#  '상추+양념장',
#  '감자고추장찌개',
#  '어묵볶음',
#  '마늘쫑건새우볶음',
#  '바나나팬케익',
#  '크림누룽지탕',
#  '소고기무우국',
#  '핫케이크',
#  '맑은콩나물국',
#  '해물죽',
#  '베이글',
#  '야채죽',
#  '볼어묵볶음',
#  '미니새송이볶음',
#  '소고기국',
#  '호박된장국',
#  '김치순두부찌개',
#  '봄동겉절이',
#  '두부고기조림',
#  '곰피초장',
#  '브로컬리들깨찜',
#  '대만샌드위치',
#  '시금치팬케익',
#  '크로크무슈',
#  '오색떡국',
#  '햄에그샌드위치',
#  '해물동그랑땡전',
#  '살라미샌드위치',
#  '연두부탕',
#  '가지볶음',
#  '가지쇠고기볶음',
#  '단배추나물',
#  '매생이국',
#  '치즈프레즐',
#  '크루통크림스프',
#  '삶은계란',
#  '새알팥죽',
#  '오이보트샐러드',
#  '대구탕',
#  '느타리애호박볶음',
#  '맑은연두부탕',
#  '마늘쫑무침',
#  '치커리오이무침',
#  '두반장가지볶음',
#  '두부떡국',
#  '바나나시나몬토스트',
#  '무비트생채',
#  '라즈베리빵',
#  '건새우무채국',
#  '참나물땅콩무침',
#  '사각어묵무침',
#  '초코핫케익',
#  '참치김치볶음',
#  '<120명',
#  '꽃게탕',
#  '북어콩나물국',
#  '스콘',
#  '맑은조개탕',
#  '땅콩아몬드조림',
#  '애플샌드',
#  '얼큰낙지죽',
#  '녹차호떡',
#  '들깨미역국',
#  '매운사태조림',
#  '톳두부무침',
#  '문어꽈리초조림',
#  '야채햄샌드',
#  '재래김',
#  '맑은순두부국',
#  '느타리팽이볶음',
#  '게살죽',
#  '호박잎찌개',
#  '취나물',
#  '근대된장국',
#  '두부들깨탕',
#  '생크림단팥빵',
#  '겨울초겉절이',
#  '콩자반',
#  '딸기파이',
#  '새송이조림',
#  '건파래무침',
#  '새우완자국',
#  '콩비지찌개',
#  '마늘쫑햄볶음',
#  '연근호두조림',
#  '더덕무침',
#  '크림롤케익',
#  '꽃게된장찌개',
#  '카레감자볶음',
#  '꽃게된장국',
#  '고기완자전',
#  '사과',
#  '땅콩멸치볶음',
#  '구운계란',
#  '햄치즈샌드',
#  '맑은감자국',
#  '늙은호박죽',
#  '콩나물해장국',
#  '참나물무침',
#  '대만식연유샌드위치',
#  '황태두부국',
#  '김치어묵국',
#  '호박젓국찌개',
#  '쑥국',
#  '참치새드',
#  '해물순두부찌개',
#  '딤섬',
#  '숙주나물',
#  '사과오이초무침',
#  '열무나물',
#  '우엉간장조림',
#  '콘스프',
#  '물파래무침',
#  '콩나물김치국',
#  '미니케익',
#  '트위스터버거',
#  '햄에그치즈토스트',
#  '닭곰탕',
#  '애호박나물',
#  '알감자조림',
#  '꽁치김치조림',
#  '참치채소볶음',
#  '소시지감자볶음',
#  '미역국',
#  '연두부찌개',
#  '과일샐러드',
#  '순두부탕',
#  '북어계란국',
#  '바지락살국',
#  '냉이된장국',
#  '도토리묵무침',
#  '비름나물',
#  '요거트D',
#  '유부김칫국',
#  '진미채볶음',
#  '배추맑은국']

# %%
len(morning_menu_list)
# Out:
# 13507

# %%
len(list(set(morning_menu_list)))
# Out:
# 787

# %%
lunch_menu_list[1]
# Out:
# '잡곡밥'

# %%
dinner_menu_list[2]
# Out:
# '육개장'

# %%
train_df.head(10)
# Out:
#      date  year month day        일자 요일    정원  휴가자  출장자  시간외근무  재택근무   근무중인원  \
# 0  160201  2016    02  01  20160201  월  2601   50  150    238     0  2639.0
# 1  160202  2016    02  02  20160202  화  2601   50  173    319     0  2697.0
# 2  160203  2016    02  03  20160203  수  2601   56  180    111     0  2476.0
# 3  160204  2016    02  04  20160204  목  2601  104  220    355     0  2632.0
# 4  160205  2016    02  05  20160205  금  2601  278  181     34     0  2176.0
# 5  160211  2016    02  11  20160211  목  2601  383  143    417     0  2492.0
# 6  160212  2016    02  12  20160212  금  2601  389  156     93     0  2149.0
# 7  160215  2016    02  15  20160215  월  2601   87  204    482     0  2792.0
# 8  160216  2016    02  16  20160216  화  2601   72  236    526     0  2819.0
# 9  160217  2016    02  17  20160217  수  2601   78  250     23     0  2296.0
#
#                                                   조식  \
# 0      모닝롤 찐빵 우유 두유 주스 계란후라이 호두죽 쌀밥 된장찌개 쥐어채무침 포기김치
# 1  모닝롤 단호박샌드 우유 두유 주스 계란후라이 팥죽 쌀밥 호박젓국찌개 시래기조림 포기김치
# 2  모닝롤 베이글 우유 두유 주스 계란후라이 표고버섯죽 쌀밥 콩나물국 느타리호박볶음 포...
# 3      모닝롤 토마토샌드 우유 두유 주스 계란후라이 닭죽 쌀밥 근대국 멸치볶음 포기김치
# 4       모닝롤 와플 우유 두유 주스 계란후라이 쇠고기죽 쌀밥 재첩국 방풍나물 포기김치
# 5     팬케익 찐빵 우유 두유 주스 계란후라이 견과류죽 쌀밥 감자찌개 명엽채무침 포기김치
# 6   모닝롤 야채샌드 우유 두유 주스 계란후라이 고구마죽 쌀밥 봄동된장국 숙주나물 포기김치
# 7    모닝롤 치즈프레즐 우유 두유 주스 계란후라이 잣죽 쌀밥 민물새우찌개 콩조림 포기김치
# 8       모닝롤 마늘빵 우유 두유 주스 계란후라이 단호박죽 쌀밥 어묵국 김구이 포기김치
# 9    모닝롤 참치샌드 우유 두유 주스 계란후라이 흑임자죽 쌀밥 북어계란국 무생채 포기김치
#
#                                              중식  \
# 0        쌀밥 잡곡밥 오징어찌개 쇠불고기 계란찜 청포묵무침 요구르트 포기김치
# 1   쌀밥 잡곡밥 김치찌개 가자미튀김 모둠소세지구이 마늘쫑무침 요구르트 배추겉절이
# 2        카레덮밥 팽이장국 치킨핑거 쫄면야채무침 견과류조림 요구르트 포기김치
# 3       쌀밥 잡곡밥 쇠고기무국 주꾸미볶음 부추전 시금치나물 요구르트 포기김치
# 4        쌀밥 잡곡밥 떡국 돈육씨앗강정 우엉잡채 청경채무침 요구르트 포기김치
# 5  쌀밥 잡곡밥 시래기국 훈제오리구이 도토리묵무침 쌈무 양파절임 요구르트 포기김치
# 6       쌀밥 잡곡밥 꽃게탕 돈육굴소스볶음 옥수수전 유채나물 요구르트 포기김치
# 7    쌀밥 잡곡밥 시금치국 닭감자조림 연두부 양념장 콩나물무침 요구르트 포기김치
# 8       쌀밥 잡곡밥 쇠고기무국 탕수어 오징어숙회무침 취나물 요구르트 포기김치
# 9   쌀밥 잡곡밥 냉이된장국 쇠고기장조림 통도라지구이 치커리무침 요구르트 포기김치
#
#                                        석식   중식계  석식계
# 0     쌀밥 잡곡밥 육개장 자반고등어구이 두부조림 건파래무침 포기김치   1039  331
# 1       콩나물밥 양념장 어묵국 유산슬 아삭고추무침 바나나 포기김치    867  560
# 2   쌀밥 잡곡밥 청국장찌개 황태양념구이 고기전 새송이버섯볶음 포기김치   1017  573
# 3       미니김밥 겨자장 우동 멕시칸샐러드 군고구마 무피클 포기김치    978  525
# 4   쌀밥 잡곡밥 차돌박이찌개 닭갈비 감자소세지볶음 콩나물무침 포기김치    925  330
# 5            참치회덮밥 맑은국 군만두 과일샐러드 락교 포기김치   1045  550
# 6      쌀밥 잡곡밥 김치콩나물국 미니함박 어묵볶음 물파래무침 깍두기    909  598
# 7  쌀밥 잡곡밥 홍합미역국 등갈비김치찜 임연수구이 브로컬리초장 포기김치   1268  672
# 8      쌀밥 잡곡밥 된장찌개 쇠불고기 해파리겨자채 봄동무침 포기김치   1014  523
# 9      볶음밥 자장소스 맑은국 새우또띠아 쨔샤이무침 요플레 포기김치    916  588

# %% [markdown]
# # EDA

# %%
train_df["year"].value_counts()
plt.pie(train_df["year"].value_counts().values, labels=train_df["year"].value_counts().index, autopct="%d%%")
plt.title('연도별 급식운영일수')
plt.show()

ax = sns.countplot(x = 'year',data = train_df)
containers = ax.containers[0]
ax.bar_label(containers, labels=[f'{x:,.0f}' for x in containers.datavalues], label_type='center')
plt.title('연도별 급식운영일수')
plt.show()

train_df["month"].value_counts()
plt.pie(train_df["month"].value_counts().values, labels=train_df["month"].value_counts().index, autopct="%d%%")
plt.title('월별 급식운영일수')
plt.show()

ax = sns.countplot(x = 'month',data = train_df, hue='year')
plt.title('월별 급식운영일수')
plt.show()

# %%
ax = sns.barplot(data=train_df, x='month', y="중식계", hue='year')
plt.title('연도별/월별/중식계')
plt.show()

ax = sns.barplot(data=train_df, x='month', y="석식계", hue='year')
plt.title('연도별/월별/석식계')
plt.show()

ax = sns.barplot(data=train_df, x='중식계', y="요일", hue='month')
plt.title('요일별/월별/중식계')
plt.show()

ax = sns.barplot(data=train_df, x='석식계', y="요일", hue='month')
plt.title('요일별/월별/석식계')
plt.show()
